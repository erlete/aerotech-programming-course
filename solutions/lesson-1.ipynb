# %% [markdown]
# # Solucionario
#
# Este es el solucionario de los ejercicios de la primera clase del curso de Python.

# %% [markdown]
# ### _Ejercicio: Creación de variables_
#
# Crea una variable llamada `my_first_variable` que contenga el valor `69`.

# %%
# Proposed solution 1:

my_first_variable: int
my_first_variable = 69

# -------------------------------------------------------------------------- #

# Proposed solution 2:

my_first_variable: int = 69

# %% [markdown]
# ### _Ejercicio: Determinación del tipo de dato de una variable_
#
# Busca información sobre la **función** que te permite pasar como argumento una variable y conocer el tipo de dato que contiene.
#
# Muestra en pantalla el tipo de dato de la variable `unknown`.

# %%
unknown = "What am I?"

# Proposed solution 1:

print(type(unknown))

# %% [markdown]
# ### _Ejercicio: Tipos de datos no secuenciales_
#
# Crea dos variables llamadas `var_1` y `var_2` que contengan, respectivamente, el valor de Pi (con cuatro decimales) y el número de horas en un día.
#
# En la misma línea de cada variable definida indica, mediante un comentario, el tipo de dato que contiene.

# %%
# Proposed solution 1:

var_1: float
var_2: int

var_1 = 3.1415  # Type: float.
var_2 = 24  # Type: int.

# -------------------------------------------------------------------------- #

# Proposed solution 2:

var_1: float = 3.1415  # Type: float.
var_2: int = 24  # Type: int.

# %% [markdown]
# ### _Ejercicio: Tipos de datos secuenciales_
#
# Crea tres variables (llámalas como quieras) que contengan los siguientes datos:
#
# 1. Lista con valores del `1` al `5` (incluidos).
# 2. Set con valores del `-2` al `0` (incluidos).
# 3. String con los caracteres `'a'`, `'b'` y `'c'`.
# 4. Lista de las palabras contenidas en la frase `"I'm learning Python"`.
# 5. Diccionario que relacione las claves de `"seconds"`, `"minutes"` y `"hours"` con la cantidad de los segundos, minutos y horas que hay en un día (respectivamente).

# %%
# Proposed solution 1:

var_1: list
var_2: set
var_3: str
var_4: list
var_5: dict

var_1 = [1, 2, 3, 4, 5]
var_2 = {-2, -1, 0}
var_3 = "abc"
var_4 = ["I'm", "learning", "Python"]
var_5 = {
    "hours": 24,
    "minutes": 1440,
    "seconds": 86400
}

# -------------------------------------------------------------------------- #

# Proposed solution 2:

var_1: list = [1, 2, 3, 4, 5]
var_2: set = {-2, -1, 0}
var_3: str = "abc"
var_4: list = ["I'm", "learning", "Python"]
var_5: dict = {
    "hours": 24,
    "minutes": 1440,
    "seconds": 86400
}

# -------------------------------------------------------------------------- #

# Proposed solution 3:

var_1: list[int] = [1, 2, 3, 4, 5]
var_2: set[int] = {-2, -1, 0}
var_3: str = "abc"
var_4: list[str] = ["I'm", "learning", "Python"]
var_5: dict[str, int] = {
    "hours": 24,
    "minutes": 1440,
    "seconds": 86400
}

# %%
# For tryhards >:)

var_1: list[int] = list(range(1, 6))

var_2: set[int] = set((num - 1) * -1 for num in var_1[:len(var_1) - 2])

var_3: str = ''.join(chr(char) for char in range(97, 100))

var_4: list[str] = ''.join(
    chr(int(code)) for code in [
        "073", "039", "109", "032", "108", "101", "097", "114", "110", "105",
        "110", "103", "032", "080", "121", "116", "104", "111", "110"
    ]
)

var_5: dict[str, int] = {
    "hours": sum(ord(char) for char in "good luck") // 37,
    "minutes": int(
        24 * 7.745966692414834 ** ((not bool()) ** bool() * (True + True))),
    "seconds": int(
        ((not bool(((((((((((((0_0)))))))))))))) + .2445980985306828) * 69420
    )
}

# -------------------------------------------------------------------------- #

# Go on, try it!

print(var_1)
print(var_2)
print(var_3)
print(var_4)
print(var_5)

# %% [markdown]
# ### _Ejercicio: Cambio de tipo de datos (1)_
#
# Convierte un `int` cualquiera a un `float` y asigna el resultado a una variable. Seguidamente, convierte un `float` cualquiera a un `int` y asigna el resultado a otra variable distinta.
#
# Finalmente, imprime los resultados en pantalla.

# %%
# Proposed solution 1:

var_1: float
var_2: int

var_1 = float(1)
var_2 = int(2.0)

print(var_1)
print(var_2)

# -------------------------------------------------------------------------- #

# Proposed solution 2:

var_1: float = float(1)
var_2: int = int(2.0)

print(var_1)
print(var_2)

# %% [markdown]
# ### _Ejercicio: Cambio de tipo de datos (2)_
#
# Prueba a crear una variable que contenga un `str` e intenta cambiar el tipo de datos de dicha variable a `int`. ¿Qué ocurre?

# %%
# Proposed solution 1:

var_1 = ""
# int(var_1)  # This statement throws a ValueError error.

# %% [markdown]
# ### _Ejercicio: Booleanos_
#
# Crea una serie de variables (mínimo 4, máximo 6) que contengan distintos tipos de datos (los que quieras, con los contenidos que te parezca) e imprime su valor booleano en pantalla.
#
# _**Sugerencia**: prueba a crear una lista vacía y una tupla con varios elementos y razona por qué sus valores booleanos son, respectivamente, `False` y `True`._

# %%
# Proposed solution 1:

var_1: list = []
var_2: tuple[int] = (1, 2, 3)
var_3: list[list] = [[]]
var_4: tuple[tuple[tuple[tuple[tuple[tuple]]]]] = (((((())))))

print(bool(var_1))  # False: empty list.
print(bool(var_2))  # True: non-empty tuple.
print(bool(var_3))  # True: list of lists.
print(bool(var_4))  # False: tuple of tuples...? >:).

# %% [markdown]
# ## _Ejercicio: Copia de listas_
#
# A partir de una variable llamada `list_1` que contiene una lista, crea otra variable llamdada `list_2` que contenga los elementos de la primera lista (sin copiarlos a mano).
#
# *__Aviso__: los elementos de ambas listas deben ser independientes (si se modifica `list_1` no se deberá modificar `list_2`).*

# %%
list_1 = [1, 2, 3, 4, 5]

# Proposed solution 1:

list_2: list[int] = list_1.copy()

# -------------------------------------------------------------------------- #

# Proposed solution 2:

list_2: list[int] = list_1[:]

# -------------------------------------------------------------------------- #

# Proposed solution 3:

list_2: list[int] = list(list_1)

# -------------------------------------------------------------------------- #

# Proposed solution 4:

list_2: list[int] = list_1[:][:][:][:][:][:][:][:][:][:][:][:][:][:]

# %% [markdown]
# ## _Ejercicio: Ordenación de listas_
#
# Dada una lista `list_1`, guarda en la variable `list_2` una copia ordenada (de menor a mayor) e independiente de la primera.
#
# _**Sugerencia**: busca el método de las listas que te se ajusta a los requisitos de este ejercicio._

# %%
list_1 = [5, 3, -1, 2, 3, 0]

# Proposed solution 1:

list_2: list[int] = sorted(list_1)  # `sorted` copies the list automatically.

# -------------------------------------------------------------------------- #

# Proposed solution 2:

# Any of the previous exercise solutions are valid here.

list_2: list[int] = list_1.copy()
list_2.sort()

# %% [markdown]
# ## _Ejercicio: Operadores aritméticos_
#
# Dadas dos tuplas de dos elementos contenidas en las variables `vector_1` y `vector_2`, crear una variable `distance` que contenga el resultado de calcular la distancia entre ambas.
#
# Sólo podrás utilizar operaciones aritméticas básicas (definidas en el apartado actual).

# %%
vector_1 = (0, 0)
vector_2 = (1, 1)

# Proposed solution 1:

distance: float = (
    (vector_2[0] - vector_1[0])**2
    + (vector_2[1] - vector_1[1])**2
) ** .5

# %% [markdown]
# ## _Ejercicio: Estructuras generadas por iteración_
#
# Genera una lista mediante una _list comprehension_ y guárdala en una variable llamada `gen_list`. La lista deberá contener un rango de valores entre `0` y `-22` con saltos de 3 en 3 y debe excluir los valores `-6` y `-18`.

# %%
# Proposed solution 1:

gen_list: list[int] = [
    num for num in range(0, -22, -3)
    if num != -6 and num != -18
]

# -------------------------------------------------------------------------- #

# Proposed solution 2:

gen_list: list[int] = [
    num for num in range(0, -22, -3)
    if num not in (-6, -18)
]

# -------------------------------------------------------------------------- #

# Proposed solution 3:

gen_list: list[int] = [
    -num for num in range(0, 22, 3)
    if num != 6 and num != 18
]

# -------------------------------------------------------------------------- #

# Proposed solution 4:

gen_list: list[int] = [
    -num for num in range(0, 22, 3)
    if num not in (6, 18)
]

# %% [markdown]
# ## _Ejercicio: Argumentos posicionales únicos y variables_
#
# Define una función que tome un argumento posicional y más argumentos variables. El primer argumento debe ser el título de una historia. Cada uno de los demás argumentos debe ser una línea de la historia, por ejemplo:
#
# > _Título (argumento posicional único)_
#
# >> _Línea 1 (argumento posicional variable 1)_
#
# >> _Línea 1 (argumento posicional variable 2)_
#
# ...
#
# >> _Línea n (argumento posicional variable n)_
#
# La función debe devolver un String con la estructura descrita y el contenido pasado a la función.
#
# _**Sugerencia**: para indentar las líneas de texto puedes utilizar el caracter escapado del tabulador '\t'. Para separar líneas puedes utilizar el caracter escapado de nueva línea '\n'._

# %%
# Proposed solution 1:

def history(title: str, *lines: tuple[str]) -> str:
    """History generation function.

    This function takes a title and lines as arguments and returns a string
    containing the title and lines formatted as a history.

    Args:
        title (str): The title of the history.
        lines (tuple[str]): The lines of the history.

    Returns:
        str: The formatted history.
    """

    output = title
    
    for line in lines:
        output += f"\n\t{line}"
    
    return output

# -------------------------------------------------------------------------- #

# Proposed solution 2:

def history(title: str, *lines: tuple[str]) -> str:
    """History generation function.

    This function takes a title and lines as arguments and returns a string
    containing the title and lines formatted as a history.

    Args:
        title (str): The title of the history.
        lines (tuple[str]): The lines of the history.

    Returns:
        str: The formatted history.
    """

    return title + ''.join(f"\n\t{line}" for line in lines)

# %% [markdown]
# ## *Ejercicio: Privatización de métodos y atributos*
#
# Crea una clase llamada Coche que contenga tres atributos: `color`, `license_plate` y `VIN_number`. Los atributos deberán ser público, protegido y privado, respectivamente.
#
# Seguidamente, crea una instancia de la clase mediante su constructor e intenta imprimir en pantalla los valores de los tres atributos creados. ¿Qué dificultades observas según incrementa el nivel de privatización?

# %%
# Proposed solution 1:

class Coche:
    """Simple car class.

    This class features a constructor method that sets the car's color,
    license plate and VIN number.

    Args:
        color (str): The car's color.
        license_plate (str): The car's license plate.
        VIN_number (str): The car's VIN number.
    """

    def __init__(self, color: str, license_plate: str, VIN_number: str):
        self.color: str = color
        self._license_plate: str = license_plate
        self.__VIN_number: str = VIN_number

obj = Coche("red", "ABC-1234", "12345678901234567")

print(obj.color)  # Simple access mode.
print(obj._license_plate)  # Requires a _ prefix for access.
print(obj._Coche__VIN_number)  # Requires a _classname__ prefix for access.

# -------------------------------------------------------------------------- #

# Proposed solution 2:

class Coche:
    """Simple car class.

    This class features a constructor method that sets the car's color,
    license plate and VIN number.

    Args:
        color (str): The car's color.
        license_plate (str): The car's license plate.
        VIN_number (str): The car's VIN number.
    """

    def __init__(self, color: str, license_plate: str, VIN_number: str):
        self.color: str = color
        self._license_plate: str = license_plate
        self.__VIN_number: str = VIN_number

    @property
    def license_plate(self) -> str:
        return self._license_plate
    
    @property
    def VIN_number(self) -> str:
        return self.__VIN_number

obj = Coche("red", "ABC-1234", "12345678901234567")

print(obj.color)
print(obj.license_plate)
print(obj.VIN_number)

# %% [markdown]
# ## _Ejercicio final_
#
# Crea una clase para manejar números complejos Esta ha de permitir suma, resta, multiplicacion, division, igualdad y ha de poder convertise en cadena con el formato "a + bi". Ten en cuenta que `i**2 = -1`.

# %%
# Proposed solution 1:

class Complex:
    """Complex number class.

    This class features a constructor method that sets the complex number's
    real and imaginary parts, as well as essential magic methods that allow
    the class to be used as an operable entity, following the rules of the
    complex number system.

    Args:
        real (int | float): The complex number's real part.
        imaginary (int | float): The complex number's imaginary part.
    """

    def __init__(self, real: int | float, imaginary: int | float) -> None:
        self._real: int | float = float(real)
        self._imaginary: int | float = float(imaginary)

    @property
    def real(self) -> int | float:
        return self._real

    @property
    def imaginary(self) -> int | float:
        return self._imaginary

    @real.setter
    def real(self, real) -> None:
        self._real = real

    @imaginary.setter
    def imaginary(self, imaginary) -> None:
        self._imaginary = imaginary

    def __add__(self, value):
        if not isinstance(value, Complex):
            raise TypeError("Added value must be a class Complex instance.")

        return Complex(
            self._real + value.real,
            self._imaginary + value.imaginary
        )

    def __sub__(self, value):
        if not isinstance(value, Complex):
            raise TypeError(
                "Subtracted value must be a class Complex instance.")

        return Complex(
            self._real - value.real,
            self._imaginary - value.imaginary
        )

    def __mul__(self, value):
        if not isinstance(value, Complex):
            raise TypeError(
                "Multiplied value must be a class Complex instance.")

        return Complex(
            self._real * value._real - self._imaginary * value._imaginary,
            self._real * value._imaginary + self._imaginary * value._real
        )

    def __truediv__(self, value):
        if not isinstance(value, Complex):
            raise TypeError("Divided value must be a class Complex instance.")

        return Complex(
            (self._real * value._real + self._imaginary * value._imaginary)
            / (value._real ** 2 + value._imaginary ** 2),
            (self._imaginary * value._real + self._real * value._imaginary)
            / (value._real ** 2 + value._imaginary ** 2)
        )

    def __eq__(self, value) -> bool:
        if not isinstance(value, Complex):
            raise TypeError(
                "Compared value must be a class Complex instance."
            )

        return not (
            self._real - value.real
            + self._imaginary - value.imaginary
        )

    def __str__(self) -> str:
        if self._imaginary < 0:
            return f"({self._real} - {abs(self._imaginary)}i)"

        return f"({self._real} + {self._imaginary}i)"


n1 = Complex(420, -69)
n2 = Complex(420, 69)

print(f"""Complex number operations:
    n1 = {n1}
    n2 = {n2}
    n1 + n2 = {n1 + n2}
    n1 - n2 = {n1 - n2}
    n1 * n2 = {n1 * n2}
    n1 / n2 = {n1 / n2}
    n1 == n2 = {n1 == n2}
""")

# -------------------------------------------------------------------------- #

# Proposed solution 2:

class Complex:
    """Predefinition of the class that allows self type hinting in the definition."""
    pass

class Complex:
    """Complex number class.

    This class features a constructor method that sets the complex number's
    real and imaginary parts, as well as essential magic methods that allow
    the class to be used as an operable entity, following the rules of the
    complex number system.

    Args:
        real (int | float): The complex number's real part.
        imaginary (int | float): The complex number's imaginary part.
    """

    def __init__(self, real: int | float, imaginary: int | float) -> None:
        self._real: int | float = float(real)
        self._imaginary: int | float = float(imaginary)

    @property
    def real(self) -> int | float:
        return self._real

    @property
    def imaginary(self) -> int | float:
        return self._imaginary

    @real.setter
    def real(self, real) -> None:
        self._real = real

    @imaginary.setter
    def imaginary(self, imaginary) -> None:
        self._imaginary = imaginary

    def __add__(self, value) -> Complex:
        if not isinstance(value, Complex):
            raise TypeError("Added value must be a class Complex instance.")

        return Complex(
            self._real + value.real,
            self._imaginary + value.imaginary
        )

    def __sub__(self, value) -> Complex:
        if not isinstance(value, Complex):
            raise TypeError(
                "Subtracted value must be a class Complex instance.")

        return Complex(
            self._real - value.real,
            self._imaginary - value.imaginary
        )

    def __mul__(self, value) -> Complex:
        if not isinstance(value, Complex):
            raise TypeError(
                "Multiplied value must be a class Complex instance.")

        return Complex(
            self._real * value._real - self._imaginary * value._imaginary,
            self._real * value._imaginary + self._imaginary * value._real
        )

    def __truediv__(self, value) -> Complex:
        if not isinstance(value, Complex):
            raise TypeError("Divided value must be a class Complex instance.")

        return Complex(
            (self._real * value._real + self._imaginary * value._imaginary)
            / (value._real ** 2 + value._imaginary ** 2),
            (self._imaginary * value._real + self._real * value._imaginary)
            / (value._real ** 2 + value._imaginary ** 2)
        )

    def __eq__(self, value) -> bool:
        if not isinstance(value, Complex):
            raise TypeError(
                "Compared value must be a class Complex instance."
            )

        return not (
            self._real - value.real
            + self._imaginary - value.imaginary
        )

    def __str__(self) -> str:
        if self._imaginary < 0:
            return f"({self._real} - {abs(self._imaginary)}i)"

        return f"({self._real} + {self._imaginary}i)"


n1 = Complex(420, -69)
n2 = Complex(420, 69)

print(f"""Complex number operations:
    n1 = {n1}
    n2 = {n2}
    n1 + n2 = {n1 + n2}
    n1 - n2 = {n1 - n2}
    n1 * n2 = {n1 * n2}
    n1 / n2 = {n1 / n2}
    n1 == n2 = {n1 == n2}
""")
